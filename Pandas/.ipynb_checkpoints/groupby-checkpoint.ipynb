# %% [markdown]
# # groupby初探

# %% [markdown]
# 本文学习https://www.jianshu.com/p/42f1d2909bb6

# %% [markdown]
# ## 1.准备数据

# %%
# 读入数据集，使用美国警方击毙数据集
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' #解决matplotlib在Retina屏幕中显示模糊问题

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from six.moves import urllib 
plt.style.use('ggplot')

# path = 'https://raw.githubusercontent.com/HoijanLai/dataset/master/PoliceKillingsUS.csv'
# data = pd.read_csv(path, encoding = 'latin1')
# data.head(10)

#下载到本地,并读取
URL = 'https://raw.githubusercontent.com/HoijanLai/dataset/master/PoliceKillingsUS.csv'
LOCALPATH = os.path.join(".", "PoliceKillingsUS.csv")

def fetch_data(url=URL,localpath=LOCALPATH):
    urllib.request.urlretrieve(url, localpath)

def load_data(path=LOCALPATH):
    return pd.read_csv(path, encoding='latin1')

fetch_data()
data = load_data()
data.head(10)
# Out:
#                   name      date race   age  signs_of_mental_illness  \
# 0           Tim Elliot  02/01/15    A  53.0                     True
# 1     Lewis Lee Lembke  02/01/15    W  47.0                    False
# 2   John Paul Quintero  03/01/15    H  23.0                    False
# 3      Matthew Hoffman  04/01/15    W  32.0                     True
# 4    Michael Rodriguez  04/01/15    H  39.0                    False
# 5    Kenneth Joe Brown  04/01/15    W  18.0                    False
# 6  Kenneth Arnold Buck  05/01/15    H  22.0                    False
# 7        Brock Nichols  06/01/15    W  35.0                    False
# 8        Autumn Steele  06/01/15    W  34.0                    False
# 9      Leslie Sapp III  06/01/15    B  47.0                    False
#
#           flee
# 0  Not fleeing
# 1  Not fleeing
# 2  Not fleeing
# 3  Not fleeing
# 4  Not fleeing
# 5  Not fleeing
# 6          Car
# 7  Not fleeing
# 8  Not fleeing
# 9  Not fleeing

# %% [markdown]
# ---

# %% [markdown]
# ## 2.什么是group by

# %% [markdown]
# groupby就是按xx分组，它也确实是用来实现这样功能的. 比如, 将一个数据集按A进行分组, 效果是这样<br>
# 我们尝试使用groupby来尝试实现这样的功能, 不过我们不用A列, 我们将用我们数据集里面的"种族"尝试分组:

# %%
data.groupby('race')

# %%
g = data.groupby('race')
g.groups
# Out:
# {'A': Int64Index([   0,   69,  155,  160,  265,  303,  337,  468,  685,  686,  766,
#               899,  945,  987, 1053, 1203, 1204, 1293, 1312, 1322, 1347, 1480,
#              1481, 1560, 1747, 1790, 1845, 1883, 1937, 1991, 1996, 2052, 2088,
#              2198, 2223, 2235, 2263, 2367, 2403],
#             dtype='int64'),
#  'B': Int64Index([   9,   11,   12,   14,   17,   26,   28,   32,   33,   39,
#              ...
#              2457, 2461, 2469, 2484, 2508, 2519, 2523, 2525, 2533, 2534],
#             dtype='int64', length=618),
#  'H': Int64Index([   2,    4,    6,   20,   22,   23,   35,   40,   41,   47,
#              ...
#              2396, 2409, 2425, 2427, 2446, 2447, 2465, 2500, 2513, 2528],
#             dtype='int64', length=423),
#  'N': Int64Index([  64,  211,  296,  438,  508,  525,  681,  684,  742, 1015, 1057,
#              1077, 1098, 1131, 1134, 1236, 1352, 1369, 1374, 1403, 1539, 1684,
#              1745, 1773, 1914, 1985, 2004, 2073, 2153, 2246, 2416],
#             dtype='int64'),
#  'O': Int64Index([  38,  327,  332,  352,  387,  524,  724,  731,  754,  812,  833,
#               905,  906,  939,  986, 1083, 1095, 1100, 1337, 1409, 1426, 1435,
#              1533, 1690, 1868, 1895, 1982, 1987],
#             dtype='int64'),
#  'W': Int64Index([   1,    3,    5,    7,    8,   10,   13,   15,   16,   18,
#              ...
#              2489, 2494, 2501, 2507, 2511, 2512, 2514, 2515, 2516, 2517],
#             dtype='int64', length=1201)}

# %% [markdown]
# 这里我们得到了一个叫___DataFrameGroupBy___的东西, 虽然 pandas 不让我们直接看它长啥样, 但是你将它想象成上面那幅分组后的图(我手绘的)是完全没有问题的.

# %% [markdown]
# >这篇稿主要介绍如何鼓捣这个___DataFrameGroupBy___, 这个___DataFrameGroupBy___主要的功能能是允许你在不额外写循环的情况下, 快速对每一组数据进行操作

# %% [markdown]
# ---

# %% [markdown]
# >！！！这里我对于groupby的理解:groupby反馈回一个带有（'race'）的____index____，然后基于__index__对(age & index)进行mean等函数进行计算

# %% [markdown]
# ## 3.基本操作

# %% [markdown]
# 最基本的就是组内计数, 求和, 求均值, 求方差, 求blablabla...
# 比如, 要求被不同种族内被击毙人员年龄的均值:

# %%
data.groupby('race')['age'].mean()
# Out:
# race
# A    36.605263
# B    31.635468
# H    32.995157
# N    30.451613
# O    33.071429
# W    40.046980
# Name: age, dtype: float64

# %% [markdown]
# 上面我们求得了各个种族中被击毙的人员的平均年龄, 得到的是一个Series, 每一行对应了每一组的mean, 除此之外你还可以换成std, median, min, max这些基本的统计数据
# 上面age是连续属性, 我们还可以操作离散属性, 比如对不同取值的计数: .value_counts()
# 以下尝试求不同种族内, 是否有精神异常迹象的分别有多少人

# %%
data.groupby('race')['signs_of_mental_illness'].value_counts()
# Out:
# race  signs_of_mental_illness
# A     False                       29
#       True                        10
# B     False                      523
#       True                        95
# H     False                      338
#       True                        85
# N     False                       23
#       True                         8
# O     False                       21
#       True                         7
# W     False                      819
#       True                       382
# Name: signs_of_mental_illness, dtype: int64

# %% [markdown]
# 注: 这时, 组内操作的结果不是单个值, 是一个序列, 我们可以用.unstack()将它展开

# %%
data.groupby('race')['signs_of_mental_illness'].value_counts().unstack()
# Out:
# signs_of_mental_illness  False  True
# race
# A                           29     10
# B                          523     95
# H                          338     85
# N                           23      8
# O                           21      7
# W                          819    382

# %% [markdown]
# >方法总结:
# - 首先通过groupby得到DataFrameGroupBy对象, 比如data.groupby('race')
# - 然后选择需要研究的列, 比如['age'], 这样我们就得到了一个SeriesGroupby, 它代表每一个组都有一个Series
# - 对SeriesGroupby进行操作, 比如.mean(), 相当于对每个组的Series求均值
# <br>注: 如果不选列, 那么第三步的操作会遍历所有列, pandas会对能成功操作的列进行操作, 最后返回的一个由操作成功的列组成的DataFrame

# %% [markdown]
# ---

# %% [markdown]
# ## 4.可视化

# %% [markdown]
# >Groupby能够帮你很轻松地分组画图, 免去手写每个组的遍历的烦恼, 还能为你每个组分好颜色.

# %% [markdown]
# ### 场景一: 不同种族中, 逃逸方式分别是如何分布的?

# %% [markdown]
# (属性A的不同分组中, 离散属性B的情况是怎么样的 )

# %% [markdown]
# - 一种传统的做法是：
#     1. 遍历每个组
#     2. 然后筛选不同组的数据
#     3. 逐个子集画条形图

# %%
races = np.sort(data['race'].dropna().unique())
fig, axes = plt.subplots(1, len(races), figsize=(24, 4), sharey=True)
for ax, race in zip(axes, races):
    data[data['race']==race]['flee'].value_counts().sort_index().plot(kind='bar', ax=ax, title=race)

# %% [markdown]
# 还不错, 但是使用Groupby能让我们直接免去循环, 而且不需要烦人的筛选, 一行就完美搞定

# %%
data.groupby('race')['flee'].value_counts().unstack().plot(kind='bar',figsize=(24,4))

# %% [markdown]
# >方法总结
# - 首先, 得到分组操作后的结果data.groupby('race')['flee'].value_counts()
# - 这里有一个之前介绍的.unstack操作, 这会让你得到一个DateFrame, 然后调用条形图, pandas就会遍历每一个组(unstack后为每一行), 然后作各组的条形图

# %% [markdown]
# ### 场景二: 按不同逃逸类型分组, 组内的年龄分布是如何的?

# %% [markdown]
# (属性A的不同分组中, 连续属性B的情况是怎么样的)

# %%
data.groupby('flee')['age'].plot(kind='kde', legend=True, figsize=(20, 5))
# Out:
# flee
# Car            AxesSubplot(0.125,0.125;0.775x0.755)
# Foot           AxesSubplot(0.125,0.125;0.775x0.755)
# Not fleeing    AxesSubplot(0.125,0.125;0.775x0.755)
# Other          AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %% [markdown]
# >方法总结<br>这里data.groupby('flee')['age']是一个SeriesGroupby对象, 顾名思义, 就是每一个组都有一个Series. 因为划分了不同逃逸类型的组, 每一组包含了组内的年龄数据, 所以直接plot相当于遍历了每一个逃逸类型, 然后分别画分布图.<br><br>
# pandas 会为不同组的作图分配颜色, 非常方便

# %% [markdown]
# ---

# %% [markdown]
# ## 高级操作

# %% [markdown]
# ### 场景三: 有时我们需要对组内不同列采取不同的操作

# %% [markdown]
# 比如说, 我们按flee分组, 但是我们需要对每一组中的年龄求中位数, 对是否有精神问题求占比

# %%
data.groupby('race').agg({'age': np.median, 'signs_of_mental_illness': np.mean})
# Out:
#        age  signs_of_mental_illness
# race
# A     35.0                 0.256410
# B     30.0                 0.153722
# H     31.0                 0.200946
# N     29.0                 0.258065
# O     29.5                 0.250000
# W     38.0                 0.318068

# %% [markdown]
# >___方法总结___
# <br>这里我们操作的data.groupby('race')是一个DataFrameGroupby, 也就是说, 每一组都有一个DataFrame<br><br>
# 我们把对这些DataFrame的操作计划写成了了一个字典{'age': np.median, 'signs_of_mental_illness': np.mean}, 然后进行agg, (aggragate, 合计)<br><br>
# 然后我们得到了一个DataFrame, 每行对应一个组, 没列对应各组DataFrame的合计信息, 比如第二行第一列表示, 黑人被击毙者中, 年龄的中位数是30, 第二行第二列表示, 黑人被击毙者中, 有精神疾病表现的占15%

# %% [markdown]
# ### 场景四: 我们需要同时求不同组内, 年龄的均值, 中位数, 方差

# %%
data.groupby('flee')['age'].agg([np.mean, np.median, np.std])
# Out:
#                   mean  median        std
# flee
# Car          33.911765    33.0  11.174234
# Foot         30.972222    30.0  10.193900
# Not fleeing  38.334753    36.0  13.527702
# Other        33.239130    33.0   9.932043

# %% [markdown]
# ### 场景五: 结合场景三和场景四可以吗?

# %%
data.groupby('flee').agg({'age': [np.median, np.mean], 'signs_of_mental_illness': np.mean})
# Out:
#                age            signs_of_mental_illness
#             median       mean                    mean
# flee
# Car           33.0  33.911765                0.114286
# Foot          30.0  30.972222                0.115646
# Not fleeing   36.0  38.334753                0.319174
# Other         33.0  33.239130                0.072917

# %% [markdown]
# 但是这里有一个问题, 这个列名分了很多层级, 我们可以进行重命名:

# %%
agg_df = data.groupby('flee').agg({'age': [np.median, np.mean], 'signs_of_mental_illness': np.mean})
agg_df.columns = ['_'.join(col).strip() for col in agg_df.columns.values]
agg_df
# Out:
#              age_median   age_mean  signs_of_mental_illness_mean
# flee
# Car                33.0  33.911765                      0.114286
# Foot               30.0  30.972222                      0.115646
# Not fleeing        36.0  38.334753                      0.319174
# Other              33.0  33.239130                      0.072917

# %% [markdown]
# ---

# %% [markdown]
# ## 总结

# %% [markdown]
# Groupby 可以简单总结为 split, apply, combine, 也就是说:
#
# - split  : 先将数据按一个属性分组 (得到 DataFrameGroupby / SeriesGroupby )
#
# - apply  : 对每一组数据进行操作 (取平均 取中值 取方差 或 自定义函数)
#
# - combine: 将操作后的结果结合起来 (得到一个DataFrame 或 Series 或可视化图像)
#
# 希望看完本文你已经对groupby的使用有清晰的印象, 并充满信心, 如果你需要更细致的微操作,  多属性Groupby等, 可以进一步阅读文档
